# %%
import pandas as pd

# %%
df = pd.read_csv("evaluation/recipes.csv")

# %%
df.head()
# Out:
#    id                               title  \
# 0   0  Chickpeas with harissa and yoghurt
# 1   1     Chickpea, spinach and egg curry
# 2   2     Tomato, chickpea and pasta soup
# 3   3      Tom Kerridge's beef stroganoff
# 4   4                         Prawn laksa
#
#                                          description  \
# 0  Chickpeas are filling, delicious, easy to cook...
# 1  This vegetarian low-calorie chickpea curry mak...
# 2  This cheap, quick and easy soup is based on an...
# 3  This classic creamy beef stroganoff recipe is ...
# 4  Fragrant, spicy and coconutty, prawn laksa is ...
#
#                                           recipeLink  \
# 0  https://www.bbc.co.uk/food/recipes/chickpeas_w...
# 1  https://www.bbc.co.uk/food/recipes/chickpea_sp...
# 2  https://www.bbc.co.uk/food/recipes/tomato_chic...
# 3  https://www.bbc.co.uk/food/recipes/beef_stroga...
# 4  https://www.bbc.co.uk/food/recipes/prawn_laksa...
#
# ...

# %%
 cuisines = df["recipeCuisine"].value_counts()
 cuisines
# Out:
# British                       872
# Italian                       587
# American                      313
# Indian                        310
# French                        216
# Thai and South-East Asian     175
# Chinese                       120
# Mexican                       107
# Turkish and Middle Eastern    107
# North African                  91
# Caribbean                      69
# Spanish                        65
# Japanese                       62
# East European                  56
# Irish                          50
# Greek                          44
# Pakistani                      42
# Korean                         38
# African                        36
# South American                 28
# Nordic                         26
# Portuguese                     16
# Name: recipeCuisine, dtype: int64

# %%
cuisines
# Out:
# British                       872
# Italian                       587
# American                      313
# Indian                        310
# French                        216
# Thai and South-East Asian     175
# Chinese                       120
# Mexican                       107
# Turkish and Middle Eastern    107
# North African                  91
# Caribbean                      69
# Spanish                        65
# Japanese                       62
# East European                  56
# Irish                          50
# Greek                          44
# Pakistani                      42
# Korean                         38
# African                        36
# South American                 28
# Nordic                         26
# Portuguese                     16
# Name: recipeCuisine, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(list(cuisines.index), list(cuisines))
# Out:
# <BarContainer object of 22 artists>
